# %%
from SQL.update_table import *

update_table_ladder(from_parquet=True)
update_table_soloq(from_parquet=True)
update_table_game_summary(from_parquet=True)

# %%
from scripts.lol_get.soloq import get_soloq_games
from common.core import convert_perks

soloq = get_soloq_games(db_engine=db_engine, riot_id='bobjenkins1', riot_tag='NA1', role='top', on_role=True, start_date='11-01-2023', end_date='12-21-2023')

convert_perks(soloq)
# Out:
#                 game_creation game_version        match_id      riot_id  \
# 0   2023-11-01 10:16:19-07:00        13.21  NA1_4817627760  bobjenkins1
# 1   2023-11-01 11:05:01-07:00        13.21  NA1_4817642413  bobjenkins1
# 2   2023-11-01 11:30:41-07:00        13.21  NA1_4817655584  bobjenkins1
# 3   2023-11-01 12:08:00-07:00        13.21  NA1_4817680865  bobjenkins1
# 4   2023-11-01 12:42:20-07:00        13.21  NA1_4817699835  bobjenkins1
# ..                        ...          ...             ...          ...
# 72  2023-12-19 16:16:53-08:00        13.24  NA1_4865363696  bobjenkins1
# 73  2023-12-20 10:44:07-08:00        13.24  NA1_4866108922  bobjenkins1
# 74  2023-12-20 11:26:46-08:00        13.24  NA1_4866136778  bobjenkins1
# 75  2023-12-20 12:04:54-08:00        13.24  NA1_4866162941  bobjenkins1
# 76  2023-12-20 13:26:09-08:00        13.24  NA1_4866219091  bobjenkins1
#
#    riot_tag team_position champion    win  gold_earned   cs  ...  \
# 0       NaN           TOP   Kennen  False        11807  221  ...
# 1       NaN           TOP   Rumble   True         7063  117  ...
# 2       NaN           TOP   Kennen  False         8639  136  ...
# 3       NaN           TOP   Kennen   True         8612  128  ...
# 4       NaN           TOP   Kennen  False        12642  225  ...
# ..      ...           ...      ...    ...          ...  ...  ...
# 72      NA1           TOP   Kennen   True         9447  159  ...
# 73      NA1           TOP   Kennen  False        11862  241  ...
# 74      NA1           TOP    Poppy   True        10571  157  ...
# 75      NA1           TOP   Kennen  False        13848  248  ...
# 76      NA1           TOP   Kennen   True         7638  137  ...
#
#     perk_primary_row_3  perk_secondary_row_1  perk_secondary_row_2  \
# 0      Gathering Storm        Taste of Blood       Ultimate Hunter
# 1               Scorch        Taste of Blood       Ultimate Hunter
# 2      Gathering Storm        Taste of Blood       Ultimate Hunter
# 3      Gathering Storm        Taste of Blood       Ultimate Hunter
# 4      Gathering Storm        Taste of Blood       Ultimate Hunter
# ..                 ...                   ...                   ...
# 72     Gathering Storm        Taste of Blood       Ultimate Hunter
# 73     Gathering Storm        Taste of Blood       Ultimate Hunter
# 74          Overgrowth      Biscuit Delivery       Time Warp Tonic
# 75     Gathering Storm        Taste of Blood       Ultimate Hunter
# 76     Gathering Storm        Taste of Blood       Ultimate Hunter
#
#     perk_primary_style  perk_secondary_style  perk_shard_defense  \
# 0              Sorcery             Precision               Armor
# 1              Sorcery             Precision        Magic Resist
# 2              Sorcery             Precision               Armor
# 3              Sorcery             Precision               Armor
# 4              Sorcery             Precision      Health Scaling
# ..                 ...                   ...                 ...
# 72             Sorcery             Precision               Armor
# 73             Sorcery             Precision               Armor
# 74             Resolve           Inspiration               Armor
# 75             Sorcery             Precision               Armor
# 76             Sorcery             Precision               Armor
#
#     perk_shard_flex  perk_shard_offense  early_surrender  surrender
# 0    Adaptive Force        Attack Speed            False      False
# 1    Adaptive Force      Adaptive Force            False       True
# 2    Adaptive Force        Attack Speed            False       True
# 3    Adaptive Force        Attack Speed            False       True
# 4    Adaptive Force        Attack Speed            False      False
# ..              ...                 ...              ...        ...
# 72   Adaptive Force        Attack Speed            False       True
# 73   Adaptive Force        Attack Speed            False      False
# 74   Adaptive Force      Adaptive Force            False       True
# 75   Adaptive Force        Attack Speed            False      False
# 76   Adaptive Force        Attack Speed            False       True
#
# [77 rows x 42 columns]
